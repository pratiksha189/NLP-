# %%
from nltk.tokenize import word_tokenize
from nltk  import pos_tag,RegexpParser

# %%
grammer="NP:{<DT><JJ><NN>}"

# %%
sent = "It was a beautifull game by him. An amazing play was witnessed"

# %%
parser = RegexpParser(grammer)

# %%
tree = parser.parse(pos_tag(word_tokenize(sent)))
tree
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\PGCP-AI\AppData\Local\Programs\Python\Python314\Lib\site-packages\IPython\core\formatters.py:406, in BaseFormatter.__call__(self, obj)
#     404     method = get_real_method(obj, self.print_method)
#     405     if method is not None:
# --> 406         return method()
#     407     return None
#     408 else:
#
# File c:\Users\PGCP-AI\AppData\Local\Programs\Python\Python314\Lib\site-packages\nltk\tree\tree.py:782, in Tree._repr_svg_(self)
#     781 def _repr_svg_(self):
# --> 782     from svgling import draw_tree
#     784     return draw_tree(self)._repr_svg_()
#
# ModuleNotFoundError: No module named 'svgling'
# Tree('S', [('It', 'PRP'), ('was', 'VBD'), Tree('NP', [('a', 'DT'), ('beautifull', 'JJ'), ('game', 'NN')]), ('by', 'IN'), ('him', 'PRP'), ('.', '.'), Tree('NP', [('An', 'DT'), ('amazing', 'JJ'), ('play', 'NN')]), ('was', 'VBD'), ('witnessed', 'VBN')])
