# %%
import requests

# %%
url = 'https://en.wikipedia.org/wiki/Rajgarh_Fort'

# %%
response = requests.get(url)
response
# Out:
# <Response [403]>

# %%
headers = {
    'user_Agent': 'Custom-Script/1.9 (tushar@gmail.com)',
    'Accept-Language':'en-US,en;q=0.5' 
}

# %%
response = requests.get(url, headers = headers)

# %%
response
# Out:
# <Response [403]>
