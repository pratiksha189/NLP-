# %%
import language_tool_python

# %%
# download the support for language
mytool = language_tool_python.LanguageTool('en-US')
# Out:
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# Cell In[5], line 2
#       1 # download the support for language
# ----> 2 mytool = language_tool_python.LanguageTool('en-US')
#
# File c:\Users\PGCP-AI\AppData\Local\Programs\Python\Python314\Lib\site-packages\language_tool_python\server.py:204, in LanguageTool.__init__(self, language, mother_tongue, remote_server, new_spellings, new_spellings_persist, host, config, language_tool_download_version, proxies)
#     202 elif not self._server_is_alive():
#     203     self._url = f"http://{self._host}:{self._port}/v2/"
# --> 204     self._start_server_on_free_port()
#     205 if language is None:
#     206     try:
#
# File c:\Users\PGCP-AI\AppData\Local\Programs\Python\Python314\Lib\site-packages\language_tool_python\server.py:939, in LanguageTool._start_server_on_free_port(self)
#     937 while True:
#     938     try:
# --> 939         self._start_local_server()
#     940         break
#     941     except ServerError:
#
# File c:\Users\PGCP-AI\AppData\Local\Programs\Python\Python314\Lib\site-packages\language_tool_python\server.py:965, in LanguageTool._start_local_server(self)
#     960 # Before starting local server, download language tool if needed.
#     962 self._local_language_tool = LocalLanguageTool.from_version_name(
#     963     self._language_tool_download_version
#     964 )
# --> 965 self._local_language_tool.download()
#     966 try:
#     967     if self._port:
#
# File c:\Users\PGCP-AI\AppData\Local\Programs\Python\Python314\Lib\site-packages\language_tool_python\download_lt.py:763, in ReleaseLocalLanguageTool.download(self)
#     756 def download(self) -> None:
#     757     """
#     758     Download and install this release version of LanguageTool.
#     759
#     760     This method checks Java compatibility, downloads the release ZIP file,
#     761     and extracts it to the download folder if not already installed.
#     762     """
# --> 763     confirm_java_compatibility(self._version_name)
#     765     download_folder = get_language_tool_download_path()
#     767     # Use the env var to the jar directory if it is defined
#     768     # otherwise look in the download directory
#
# File c:\Users\PGCP-AI\AppData\Local\Programs\Python\Python314\Lib\site-packages\language_tool_python\download_lt.py:239, in confirm_java_compatibility(language_tool_version)
#     235 if (major_version == 1 and minor_version < 17) or (
#     236     major_version != 1 and major_version < 17
#     237 ):
#     238     err = f"Detected java {major_version}.{minor_version}. LanguageTool requires Java >= 17 for version {language_tool_version}."
# --> 239     raise SystemError(err)
#
# SystemError: Detected java 11.0. LanguageTool requires Java >= 17 for version 6.8.
