# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.wsd import lesk

# %%
sent1="I went to bank to deposit my money."
sent2="We pitched our tent by the bank of river."

# %%
sense1=lesk(word_tokenize(sent1),'bank','n')

# %%
sense2=lesk(word_tokenize(sent2),'bank','n')

# %%
sense1.definition()
# Out:
# 'a financial institution that accepts deposits and channels the money into lending activities'

# %%
sense2.definition()
# Out:
# 'sloping land (especially the slope beside a body of water)'

# %%
nltk.__version__
# Out:
# '3.9.4'

# %%
sent3="I spread sweet strawberry jam on my toast for breakfast"

# %%
sense3=lesk(word_tokenize(sent3),'jam','n')

# %%
sense3.definition()
# Out:
# 'informal terms for a difficult situation'

# %%
sent4="I was late to work beacause I was stuck in massive traffic jam"

# %%
sense4=lesk(word_tokenize(sent4),'jam','n')

# %%
sense4.definition()
# Out:
# 'preserve of crushed fruit'

# %%
sent5= "The strong ocean current swept the swimmer a mile down the beach."
sent6="Turn off the main breaker switch before working on the electrical current."

# %%
sense5=lesk(word_tokenize(sent5),'current','n')

# %%
sense5.definition()
# Out:
# 'a flow of electricity through a conductor'

# %%
sense6=lesk(word_tokenize(sent6),'current','n')

# %%
sense6.definition()
# Out:
# 'a flow of electricity through a conductor'

# %%
sent7= "The small bat flew out dark cave and into the night sky."
sent8= "The cricket player swung the wooden bat and hit a massive six"

# %%
sense7=lesk(word_tokenize(sent7),'bat','n')

# %%
sense7.definition()
# Out:
# 'nocturnal mouselike mammal with forelimbs modified to form membranous wings and anatomical adaptations for echolocation by which they navigate'

# %%
sense8=lesk(word_tokenize(sent8),'bat','n')

# %%
sense8.definition()
# Out:
# '(baseball) a turn trying to get a hit'
