# %%
# !pip install pyiwn
# Out:
# ...
# [notice] A new release of pip is available: 26.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pyiwn
# Out:
# 2026-05-30:12:26:04,289 INFO     [helpers.py:20] Downloading IndoWordNet data of size ~31 MB...
# [██████████████████████████████████████████████████]
# 2026-05-30:12:26:20,76 INFO     [helpers.py:43] Extracting C:\Users\PGCP-AI\iwn_data.tar.gz into C:\Users\PGCP-AI...
# 2026-05-30:12:26:20,619 INFO     [helpers.py:48] Removing temporary zip file from C:\Users\PGCP-AI\iwn_data.tar.gz
# 2026-05-30:12:26:20,625 INFO     [helpers.py:51] IndoWordNet data successfully downloaded at C:\Users\PGCP-AI\iwn_data

# %%
iwn = pyiwn.IndoWordNet(lang=pyiwn.Language.MARATHI)
# Out:
# 2026-05-30:12:27:56,483 INFO     [iwn.py:43] Loading marathi language synsets...
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 iwn = pyiwn.IndoWordNet(lang=pyiwn.Language.MARATHI)
#
# File c:\Users\PGCP-AI\AppData\Local\Programs\Python\Python314\Lib\site-packages\pyiwn\iwn.py:45, in IndoWordNet.__init__(self, lang)
#      43 logger.info(f'Loading {lang.value} language synsets...')
#      44 self._synset_idx_map = {}
# ---> 45 self._synset_df = self._load_synset_file(lang.value)
#      46 self._synset_relations_dict = self._load_synset_relations()
#
# File c:\Users\PGCP-AI\AppData\Local\Programs\Python\Python314\Lib\site-packages\pyiwn\iwn.py:51, in IndoWordNet._load_synset_file(self, lang)
#      49 filename = os.path.join(*[constants.IWN_DATA_PATH, 'synsets', 'all.{}'.format(lang)])
#      50 f = open(filename)
# ...
