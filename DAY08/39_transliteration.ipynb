# %%
# !pip install indic-transliteration
# Out:
# ...
#   Using cached click-8.4.1-py3-none-any.whl.metadata (2.6 kB)
# ...
# Using cached click-8.4.1-py3-none-any.whl (116 kB)
# ...
#
#   Attempting uninstall: click
#
#     Found existing installation: click 8.1.8
#
#    ---------- ----------------------------- 1/4 [click]
#     Uninstalling click-8.1.8:
#    ---------- ----------------------------- 1/4 [click]
#       Successfully uninstalled click-8.1.8
#    ---------- ----------------------------- 1/4 [click]
#    ---------- ----------------------------- 1/4 [click]
#    ---------- ----------------------------- 1/4 [click]
#    ---------- ----------------------------- 1/4 [click]
#    -------------------- ------------------- 2/4 [backports.functools_lru_cache]
#    ------------------------------ --------- 3/4 [indic-transliteration]
#    ------------------------------ --------- 3/4 [indic-transliteration]
#    ------------------------------ --------- 3/4 [indic-transliteration]
# ...

# %%
from indic_transliteration import sanscript
from indic_transliteration.sanscript import transliterate

# %%
text1 = 'prateekShaa'
text2 = 'vijaya'

# %%
itext = transliterate(text2, sanscript.ITRANS, sanscript.DEVANAGARI)

# %%
itext
# Out:
# 'विजय'
