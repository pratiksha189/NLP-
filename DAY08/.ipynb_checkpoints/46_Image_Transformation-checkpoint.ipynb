# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img=cv2.imread('mages/dog.jpg')

# %%
q_width,q_height=img.shape[1]//4,img.shape[0]//4
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 q_width,q_height=img.shape[1]//4,img.shape[0]//4
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
T = np.float32([[1, 0, q_width], [0, 1, q_height]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 T = np.float32([[1, 0, q_width], [0, 1, q_height]])
#
# NameError: name 'q_width' is not defined

# %%
T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 T
#
# NameError: name 'T' is not defined

# %%
trans_img = cv2.warpAffine(img, T, ())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 trans_img = cv2.warpAffine(img, T, ())
#
# NameError: name 'T' is not defined
