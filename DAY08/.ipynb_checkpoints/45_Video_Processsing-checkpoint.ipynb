# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
## load the video

vid=cv2.VideoCapture('image/nature.mp4')
vid
# Out:
# < cv2.VideoCapture 0000015F08914AD0>

# %%
ret,frame=vid.read()

# %%
ret
# Out:
# False

# %%
frame

# %%
cv2.imshow('First Frame',frame)
cv2.waitKey(0)
cv2.destroyWindow()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 cv2.imshow('First Frame',frame)
#       2 cv2.waitKey(0)
#       3 cv2.destroyWindow()
#
# error: OpenCV(4.13.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:973: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'cv::imshow'
