# %%
pip install textblob
# Out:
# Requirement already satisfied: textblob in c:\Users\PGCP-AI\AppData\Local\Programs\Python\Python314\Lib\site-packages (0.20.0)
# Requirement already satisfied: nltk>=3.9 in c:\Users\PGCP-AI\AppData\Local\Programs\Python\Python314\Lib\site-packages (from textblob) (3.9.4)
# Requirement already satisfied: click in c:\Users\PGCP-AI\AppData\Local\Programs\Python\Python314\Lib\site-packages (from nltk>=3.9->textblob) (8.4.1)
# Requirement already satisfied: joblib in c:\Users\PGCP-AI\AppData\Local\Programs\Python\Python314\Lib\site-packages (from nltk>=3.9->textblob) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\Users\PGCP-AI\AppData\Local\Programs\Python\Python314\Lib\site-packages (from nltk>=3.9->textblob) (2026.4.4)
# Requirement already satisfied: tqdm in c:\Users\PGCP-AI\AppData\Local\Programs\Python\Python314\Lib\site-packages (from nltk>=3.9->textblob) (4.67.3)
# Requirement already satisfied: colorama in c:\Users\PGCP-AI\AppData\Local\Programs\Python\Python314\Lib\site-packages (from click->nltk>=3.9->textblob) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
from textblob import TextBlob

# %%
word='computar'

# %%
blob= TextBlob(word)

# %%
blob.correct()
# Out:
# TextBlob("computer")

# %%
sent='It was a grrat day. When they played on the ground'

# %%
blob=TextBlob(sent)
blob.correct()
# Out:
# TextBlob("It was a great day. When they played on the ground")

# %%
blob.correct().word_counts
# Out:
# defaultdict(int,
#             {'it': 1,
#              'was': 1,
#              'a': 1,
#              'great': 1,
#              'day': 1,
#              'when': 1,
#              'they': 1,
#              'played': 1,
#              'on': 1,
#              'the': 1,
#              'ground': 1})

# %%
blob.correct().tokenize()
# Out:
# WordList(['It', 'was', 'a', 'great', 'day', '.', 'When', 'they', 'played', 'on', 'the', 'ground'])

# %%
blob.correct().sentences
# Out:
# [Sentence("It was a great day."), Sentence("When they played on the ground")]
