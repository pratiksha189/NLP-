# %% [markdown]
# ## Pratiksha Dhembare
# ## 260240128031
#
# ## Vijay Rajage
# ## 260240128053

# %% [markdown]
# # ASSIGNMENT NUMBER : 05

# %%
# 1. Download the data from the link below using web scrapping:
# https://en.wikipedia.org/wiki/Mount_Everest
# Find the count of Total “Mount” in the text.
# Save the extracted plain text contents in file mount.txt in upper case.
# Print the title of this page.

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://en.wikipedia.org/wiki/Mount_Everest"
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
plain_text = soup.get_text()
plain_text
# Out:
# 'Please set a user-agent and respect our robot policy https://w.wiki/4wJS. See also https://phabricator.wikimedia.org/T400119.\n'

# %%
mount_count = plain_text.count("Mount")
print(f"Total count of 'Mount': {mount_count}")
# Out:
# Total count of 'Mount': 0

# %%
with open("mount.txt", "w", encoding="utf-8") as file:
    file.write(plain_text.upper())

page_title = soup.title.string if soup.title else "No title found"
print(f"Page Title: {page_title}")
# Out:
# Page Title: No title found
