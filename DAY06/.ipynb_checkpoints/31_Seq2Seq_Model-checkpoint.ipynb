# %% [markdown]
# # Seq2Seq:
# Designed for tasks involving sequential Data.\n
# takes input sequence, p[rocesses it and generates an o/p sequence] \n
# Consists of : 1. ENCODER 2. DECODER \n
# improved qwality of machine translation systems.
