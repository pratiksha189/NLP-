# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in c:\users\pgcp-ai\.conda\envs\dl_env\lib\site-packages (5.10.1)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in c:\users\pgcp-ai\.conda\envs\dl_env\lib\site-packages (from transformers) (1.17.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\pgcp-ai\.conda\envs\dl_env\lib\site-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\pgcp-ai\.conda\envs\dl_env\lib\site-packages (from transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\pgcp-ai\.conda\envs\dl_env\lib\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in c:\users\pgcp-ai\.conda\envs\dl_env\lib\site-packages (from transformers) (2026.5.9)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\pgcp-ai\.conda\envs\dl_env\lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in c:\users\pgcp-ai\.conda\envs\dl_env\lib\site-packages (from transformers) (0.25.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\pgcp-ai\.conda\envs\dl_env\lib\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\pgcp-ai\.conda\envs\dl_env\lib\site-packages (from transformers) (4.67.3)
# Requirement already satisfied: click>=8.4.0 in c:\users\pgcp-ai\.conda\envs\dl_env\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\pgcp-ai\.conda\envs\dl_env\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\pgcp-ai\.conda\envs\dl_env\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (2026.4.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in c:\users\pgcp-ai\.conda\envs\dl_env\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.5.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\pgcp-ai\.conda\envs\dl_env\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\pgcp-ai\.conda\envs\dl_env\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: anyio in c:\users\pgcp-ai\.conda\envs\dl_env\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.13.0)
# Requirement already satisfied: certifi in c:\users\pgcp-ai\.conda\envs\dl_env\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in c:\users\pgcp-ai\.conda\envs\dl_env\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in c:\users\pgcp-ai\.conda\envs\dl_env\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.13)
# Requirement already satisfied: h11>=0.16 in c:\users\pgcp-ai\.conda\envs\dl_env\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\pgcp-ai\.conda\envs\dl_env\lib\site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in c:\users\pgcp-ai\.conda\envs\dl_env\lib\site-packages (from typer->transformers) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\pgcp-ai\.conda\envs\dl_env\lib\site-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: colorama in c:\users\pgcp-ai\.conda\envs\dl_env\lib\site-packages (from click>=8.4.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.4.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\pgcp-ai\.conda\envs\dl_env\lib\site-packages (from rich>=13.8.0->typer->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\pgcp-ai\.conda\envs\dl_env\lib\site-packages (from rich>=13.8.0->typer->transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\pgcp-ai\.conda\envs\dl_env\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers) (0.1.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\pgcp-ai\.conda\envs\dl_env\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.3.1)
# [notice] A new release of pip is available: 26.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Text Classification

# %%
from transformers import pipeline

pipe = pipeline("text-generation", model="distilbert/distilgpt2")
# Out:
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.

# %%
classifier=pipeline('text-classification')
# Out:
# [transformers] No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]

# %%
import pandas as pd
text = 'It was possible for him.so he did it.'
result=classifier(text)
result
# Out:
# [{'label': 'POSITIVE', 'score': 0.9747905731201172}]

# %%
df=pd.DataFrame(result)
df
# Out:
#       label     score
# 0  POSITIVE  0.974791

# %%
text = 'Nothing is impossible without these efforts!'
results = classifier(text)
df = pd.DataFrame(results)
df
# Out:
#       label     score
# 0  POSITIVE  0.996524

# %%
text = 'Nothing is possible without these efforts!'
result = classifier(text)
df = pd.DataFrame(result)
df
# Out:
#       label     score
# 0  POSITIVE  0.994458

# %%
text = 'It was so impressive but not upto the mark.'
result = classifier(text)
df = pd.DataFrame(result)
df
# Out:
#       label     score
# 0  NEGATIVE  0.983271

# %%
text =  '''Hi [PRATIKSHA], thank you for the wonderful review! We are so glad you loved 
 the new [Product/Feature]—our team worked hard to bring this to life, 
and your feedback makes their day.'''
result = classifier(text)
df = pd.DataFrame(result)
df
# Out:
#       label     score
# 0  POSITIVE  0.999838

# %%
text =  '''Life is full of beautiful moments waiting to be discovered if we just take a second to look around. Every single day brings a fresh start, a clean slate, and a brand-new opportunity to chase your dreams and spread kindness. Remember that you are entirely capable of handling whatever comes your way, and your potential is truly limitless. Trust the timing of your unique journey, celebrate your small wins, and never forget the incredible strength you carry within yourself. Surround yourself with laughter, embrace the lessons in every challenge, and keep moving forward with an open, hopeful heart. You are doing much better than you think you are, and the future holds so many bright things just for you!'''
result = classifier(text)
df = pd.DataFrame(result)
df
# Out:
#       label     score
# 0  POSITIVE  0.999823

# %%
ner = pipeline('token-classification')
result=ner(text)
df = pd.DataFrame(result)
df
# Out:
# [transformers] No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english and revision 4c53496.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/998 [00:00<?, ?B/s]
# c:\Users\PGCP-AI\.conda\envs\dl_env\lib\site-packages\huggingface_hub\file_download.py:138: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\PGCP-AI\.cache\huggingface\hub\models--dbmdz--bert-large-cased-finetuned-conll03-english. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# c:\Users\PGCP-AI\.conda\envs\dl_env\lib\site-packages\huggingface_hub\file_download.py:744: UserWarning: Not enough free disk space to download the file. The expected file size is: 1334.40 MB. The target location C:\Users\PGCP-AI\.cache\huggingface\hub\models--dbmdz--bert-large-cased-finetuned-conll03-english\blobs only has 585.55 MB free disk space.
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# c:\Users\PGCP-AI\.conda\envs\dl_env\lib\site-packages\huggingface_hub\file_download.py:744: UserWarning: Not enough free disk space to download the file. The expected file size is: 1334.40 MB. The target location C:\Users\PGCP-AI\.cache\huggingface\hub\models--dbmdz--bert-large-cased-finetuned-conll03-english\blobs only has 33.77 MB free disk space.
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# [transformers] BertForTokenClassification LOAD REPORT from: dbmdz/bert-large-cased-finetuned-conll03-english
# Key                      | Status     |  |
# -------------------------+------------+--+-
# bert.pooler.dense.weight | UNEXPECTED |  |
# bert.pooler.dense.bias   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# [transformers] Falling back to torch.float32 because loading with the original dtype failed on the target device.
# tokenizer_config.json:   0%|          | 0.00/60.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# Empty DataFrame
# Columns: []
# Index: []

# %%
qa=pipeline('question-answering')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 qa=pipeline('question-answering')
#
# File c:\Users\PGCP-AI\.conda\envs\dl_env\lib\site-packages\transformers\pipelines\__init__.py:945, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     938         pipeline_class = get_class_from_dynamic_module(
#     939             class_ref,
#     940             model,
#     941             code_revision=code_revision,
#     942             **hub_kwargs,
#     943         )
#     944 else:
# --> 945     normalized_task, targeted_task, task_options = check_task(task)
#     946     if pipeline_class is None:
#     947         pipeline_class = targeted_task["impl"]
#
# File c:\Users\PGCP-AI\.conda\envs\dl_env\lib\site-packages\transformers\pipelines\__init__.py:357, in check_task(task)
#     321 def check_task(task: str) -> tuple[str, dict, Any]:
#     322     """
#     323     Checks an incoming task string, to validate it's correct and return the default Pipeline and Model classes, and
#     324     default models if they exist.
#    (...)
#     355
#     356     """
# --> 357     return PIPELINE_REGISTRY.check_task(task)
#
# File c:\Users\PGCP-AI\.conda\envs\dl_env\lib\site-packages\transformers\pipelines\base.py:1340, in PipelineRegistry.check_task(self, task)
#    1337     targeted_task = self.supported_tasks[task]
#    1338     return task, targeted_task, None
# -> 1340 raise KeyError(f"Unknown task {task}, available tasks are {self.get_supported_tasks()}")
#
# KeyError: "Unknown task question-answering, available tasks are ['any-to-any', 'audio-classification', 'automatic-speech-recognition', 'depth-estimation', 'document-question-answering', 'feature-extraction', 'fill-mask', 'image-classification', 'image-feature-extraction', 'image-segmentation', 'image-text-to-text', 'keypoint-matching', 'mask-generation', 'ner', 'object-detection', 'sentiment-analysis', 'table-question-answering', 'text-classification', 'text-generation', 'text-to-audio', 'text-to-speech', 'token-classification', 'video-classification', 'zero-shot-audio-classification', 'zero-shot-classification', 'zero-shot-image-classification', 'zero-shot-object-detection']"
