# %% [markdown]
# ## GloVe

# %%
import numpy as np
from gensim.models import KeyedVectors
from gensim.scripts.glove2word2vec import glove2word2vec

# %%
from gensim.models import KeyedVectors

# Since your file already has the '8 4' header, load it directly as a Word2Vec file!
model = KeyedVectors.load_word2vec_format('../DATASETS/test_glove.txt', binary=False)

# Test the similarities right below it
print("King vs Queen:", model.similarity('king', 'queen'))
print("Mango vs Apple:", model.similarity('mango', 'apple'))
# Out:
# King vs Queen: 0.9998945
# Mango vs Apple: 0.99897045

# %%
model.similarity('king', 'queen')
# Out:
# 0.9998945

# %%
model.similarity('mango', 'apple')
# Out:
# 0.99897045

# %%
model.similarity('computer', 'woman')
# Out:
# -0.61038744

# %%
model.similarity('king', 'apple')
# Out:
# 0.4803489

# %% [markdown]
# ## VISUALIZE

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
pca = PCA(n_components=2, random_state=0)

# %%
vectors_2d = pca.fit_transform(model.vectors)

vectors_2d
# Out:
# array([[-0.68762124, -0.35608202],
#        [-0.7569957 , -0.3840752 ],
#        [-0.39322007, -0.14959295],
#        [-0.4625945 , -0.17758611],
#        [-0.38705248,  0.6145134 ],
#        [-0.3594681 ,  0.59929883],
#        [ 1.4869586 , -0.07137666],
#        [ 1.5599931 , -0.07509939]], dtype=float32)

# %%
model.index_to_key
# Out:
# ['king', 'queen', 'man', 'woman', 'apple', 'mango', 'computer', 'keyboard']

# %%
plt.figure(figsize=(16,9))
plt.grid()
plt.scatter(vectors_2d[:,0], vectors_2d[:,1], color = 'r')
for i, word in enumerate(model.index_to_key):
    plt.annotate(word, xy=(vectors_2d[i,0], vectors_2d[i,1]),
                 ha='right', va='bottom')
