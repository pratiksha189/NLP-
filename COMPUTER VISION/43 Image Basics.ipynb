# %%
pip install opencv-python scikit-image pillow
# Out:
# Requirement already satisfied: opencv-python in c:\Users\PGCP-AI\AppData\Local\Programs\Python\Python314\Lib\site-packages (4.13.0.92)
# Requirement already satisfied: scikit-image in c:\Users\PGCP-AI\AppData\Local\Programs\Python\Python314\Lib\site-packages (0.26.0)
# Requirement already satisfied: pillow in c:\Users\PGCP-AI\AppData\Local\Programs\Python\Python314\Lib\site-packages (12.1.1)
# Requirement already satisfied: numpy>=2 in c:\Users\PGCP-AI\AppData\Local\Programs\Python\Python314\Lib\site-packages (from opencv-python) (2.4.2)
# Requirement already satisfied: scipy>=1.11.4 in c:\Users\PGCP-AI\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-image) (1.17.1)
# Requirement already satisfied: networkx>=3.0 in c:\Users\PGCP-AI\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-image) (3.6.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in c:\Users\PGCP-AI\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-image) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\Users\PGCP-AI\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-image) (2026.6.1)
# Requirement already satisfied: packaging>=21 in c:\Users\PGCP-AI\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-image) (26.0)
# Requirement already satisfied: lazy-loader>=0.4 in c:\Users\PGCP-AI\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-image) (0.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
#### Download the images from https://mitu.co.in/dataset

# %% [markdown]
# #### openCV

# %%
import cv2

# %%
# Load the images
img_cv =cv2.imread('images/dog.jpg')
img_cv
# Out:
# array([[[123, 188, 166],
#         [123, 188, 166],
#         [124, 189, 167],
#         ...,
#         [117, 184, 163],
#         [116, 183, 162],
#         [115, 182, 161]],
#
#        [[123, 188, 166],
#         [123, 188, 166],
#         [124, 189, 167],
#         ...,
#         [117, 184, 163],
#         [117, 184, 163],
#         [116, 183, 162]],
#
#        [[123, 188, 166],
#         [124, 189, 167],
#         [124, 189, 167],
#         ...,
#         [118, 185, 164],
#         [118, 185, 164],
#         [117, 184, 163]],
#
#        ...,
#
#        [[ 61, 123, 101],
#         [ 60, 122, 100],
#         [ 61, 123, 101],
#         ...,
#         [ 69, 124, 121],
#         [ 67, 122, 119],
#         [ 66, 121, 118]],
#
#        [[ 58, 122, 100],
#         [ 57, 121,  99],
#         [ 58, 120,  98],
#         ...,
#         [ 71, 128, 120],
#         [ 69, 125, 120],
#         [ 71, 125, 120]],
#
#        [[ 56, 121,  99],
#         [ 56, 121,  99],
#         [ 59, 121,  99],
#         ...,
#         [ 71, 128, 119],
#         [ 71, 128, 120],
#         [ 72, 126, 121]]], shape=(400, 401, 3), dtype=uint8)

# %%
type(img_cv)
# Out:
# numpy.ndarray

# %%
img_cv.shape
# Out:
# (400, 401, 3)

# %%
cv2.imshow('My image',img_cv)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### matplotlib

# %%
import matplotlib.pyplot as plt

# %%
img_plt=plt.imread('images/dog.jpg')
type(img_plt)
# Out:
# numpy.ndarray

# %%
img_plt.shape
# Out:
# (400, 401, 3)

# %%
plt.imshow(img_plt)

# %% [markdown]
# #### scikit_image

# %%
from skimage import io

# %%
img_sk = io.imread('images/dog.jpg')

# %%
type(img_sk)
# Out:
# numpy.ndarray

# %%
img_sk.shape
# Out:
# (400, 401, 3)

# %%
io.imshow(img_sk)
# Out:
# C:\Users\PGCP-AI\AppData\Local\Temp\ipykernel_15708\2086481906.py:1: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(img_sk)

# %% [markdown]
# ### PIL

# %%
from PIL import Image

# %%
img_pil=Image.open('images/dog.jpg')

# %%
type(img_pil)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
img_pil.show()

# %%
# Cell 39
img_gray = cv2.imread('images/dog.jpg', 0)

# %%
# Grayscale image
# Cell 41
# Add the cmap='gray' parameter to fix the color rendering
plt.imshow(img_gray, cmap='gray')

# %%
img_gray.shape

plt.imshow(img_gray)

# %%
img_new=cv2.cvtColor(img_cv, cv2.COLOR_RGB2GRAY)

# %%
img_new.shape
# Out:
# (400, 401)

# %%
plt.imshow(img_new,cmap='gray')

# %%
img_new.shape[0]*img_new.shape[1]
# Out:
# 160400

# %%
import numpy as np

# %%
imgz = np.zeros([500, 500], dtype = np.uint8)

# %%
imgz.dtype
# Out:
# dtype('uint8')

# %%
plt.imshow(imgz, cmap='gray')

# %%
imgz[250,:]=255

# %%
plt.imshow(imgz,cmap='gray')

# %%
imgz[:,250]=255

# %%
plt.imshow(imgz,cmap='gray')

# %%
imgz[:101,:101]=255

# %%
plt.imshow(imgz,cmap='gray')

# %%
for i in range(100,251):
    imgz[i,i] = 255

# %%
plt.imshow(imgz,cmap='gray')

# %%
sample_img = np.zeros([1000000],dtype = np.uint8)

# %%
for i in range(1000000):
    sample_img[i] = np.random.randint(0,255)

# %%
sample_img = sample_img.reshape(1000 , 1000)

# %%
plt.imshow(sample_img,cmap='gray')

# %%
chess = np.zeros([8,8])
for i in range(8):
    for j in range(8):
        if (i+j) % 2 == 0:
            chess[i,j] = 1

# %%
plt.imshow(chess,cmap='gray')

# %%
img_plt[0,0]
# Out:
# array([166, 188, 123], dtype=uint8)

# %%
# Orange - 255 , 165, 0
# Green - 0 , 255 , 0
# White - 255 , 0, 0

import numpy as np
import matplotlib.pyplot as plt

# 1. Initialize a 300x400 RGB image with zeros (Height=300, Width=400, Channels=3)
# Using uint8 data type for standard pixel values (0-255)
flag = np.zeros([300, 400, 3], dtype=np.uint8)

# 2. Assign the top band (Rows 0 to 100) -> Saffron / Orange [R=255, G=153, B=51]
flag[0:100, :, 0] = 255  # Red channel
flag[0:100, :, 1] = 153  # Green channel
flag[0:100, :, 2] = 51   # Blue channel

# 3. Assign the middle band (Rows 100 to 200) -> White [R=255, G=255, B=255]
flag[100:200, :, :] = 255 # Sets all three color channels to max brightness

# 4. Assign the bottom band (Rows 200 to 300) -> India Green [R=19, G=136, B=8]
flag[200:300, :, 0] = 19   # Red channel
flag[200:300, :, 1] = 136  # Green channel
flag[200:300, :, 2] = 8    # Blue channel

# 5. Display the generated image array using Matplotlib
plt.imshow(flag)

# %%
import matplotlib.pyplot as plt

# %%
logo=plt.imread("images/CDAC_LOGO.png")

# %%
logo.shape
# Out:
# (956, 1838, 4)

# %%
plt.imshow(logo)

# %%
img_plt = plt.imread('images/dog.jpg')
img_plt
# Out:
# array([[[166, 188, 123],
#         [166, 188, 123],
#         [167, 189, 124],
#         ...,
#         [163, 184, 117],
#         [162, 183, 116],
#         [161, 182, 115]],
#
#        [[166, 188, 123],
#         [166, 188, 123],
#         [167, 189, 124],
#         ...,
#         [163, 184, 117],
#         [163, 184, 117],
#         [162, 183, 116]],
#
#        [[166, 188, 123],
#         [167, 189, 124],
#         [167, 189, 124],
#         ...,
#         [164, 185, 118],
#         [164, 185, 118],
#         [163, 184, 117]],
#
#        ...,
#
#        [[101, 123,  61],
#         [100, 122,  60],
#         [101, 123,  61],
#         ...,
#         [121, 124,  69],
#         [119, 122,  67],
#         [118, 121,  66]],
#
#        [[100, 122,  58],
#         [ 99, 121,  57],
#         [ 98, 120,  58],
#         ...,
#         [120, 128,  71],
#         [120, 125,  69],
#         [120, 125,  71]],
#
#        [[ 99, 121,  56],
#         [ 99, 121,  56],
#         [ 99, 121,  59],
#         ...,
#         [119, 128,  71],
#         [120, 128,  71],
#         [121, 126,  72]]], shape=(400, 401, 3), dtype=uint8)

# %%
img_plt.shape
# Out:
# (400, 401, 3)

# %%
## array slicing RGB

# %%
red = img_plt[:, :, 0]
red
# Out:
# array([[166, 166, 167, ..., 163, 162, 161],
#        [166, 166, 167, ..., 163, 163, 162],
#        [166, 167, 167, ..., 164, 164, 163],
#        ...,
#        [101, 100, 101, ..., 121, 119, 118],
#        [100,  99,  98, ..., 120, 120, 120],
#        [ 99,  99,  99, ..., 119, 120, 121]], shape=(400, 401), dtype=uint8)

# %%
green = img_plt[:, :, 1]
green
# Out:
# array([[188, 188, 189, ..., 184, 183, 182],
#        [188, 188, 189, ..., 184, 184, 183],
#        [188, 189, 189, ..., 185, 185, 184],
#        ...,
#        [123, 122, 123, ..., 124, 122, 121],
#        [122, 121, 120, ..., 128, 125, 125],
#        [121, 121, 121, ..., 128, 128, 126]], shape=(400, 401), dtype=uint8)

# %%
blue = img_plt[:, :, 2]
blue
# Out:
# array([[123, 123, 124, ..., 117, 116, 115],
#        [123, 123, 124, ..., 117, 117, 116],
#        [123, 124, 124, ..., 118, 118, 117],
#        ...,
#        [ 61,  60,  61, ...,  69,  67,  66],
#        [ 58,  57,  58, ...,  71,  69,  71],
#        [ 56,  56,  59, ...,  71,  71,  72]], shape=(400, 401), dtype=uint8)

# %%
plt.subplot(1,3,1)
plt.imshow(red,cmap='gray')

# %%
plt.subplot(1,3,2)
plt.imshow(green,cmap='gray')

# %%
plt.subplot(1,3,3)
plt.imshow(blue,cmap='gray')

# %%
red.shape,green.shape,blue.shape
# Out:
# ((400, 401), (400, 401), (400, 401))

# %%
img_avg = (red // 3) + (green // 3) + (blue // 3)

# %%
plt.imshow(img_avg,cmap='gray')

# %%
## another way using split function

# %%
red,gree,blue=cv2.split(img_plt)

# %%
red.shape,green.shape,blue.shape
# Out:
# ((400, 401), (400, 401), (400, 401))

# %%
img_new=cv2.merge([red,green,blue])

# %%
plt.imshow(img_new)

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(img_plt)
plt.subplot(1,2,2)
plt.imshow(img_cv)

# %% [markdown]
# ## convert BGR to RGB

# %%
img_rgb = cv2.cvtColor(img_cv, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %% [markdown]
# ### image normalization

# %%
img_norm=img_plt/255

# %%
plt.imshow(img_norm)

# %%
img_norm.dtype
# Out:
# dtype('float64')

# %%
img_plt.dtype
# Out:
# dtype('uint8')

# %%
img_cv.dtype
# Out:
# dtype('uint8')

# %%
img_sk.dtype
# Out:
# dtype('uint8')
