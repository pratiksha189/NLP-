# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img=cv2.imread('../DATASETS/images/dog.jpg',0)

# %% [markdown]
# * BIANRY THRESHOLDING

# %%
binary_image = img > 128
binary_image
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 binary_image = img > 128
#       2 binary_image
#
# TypeError: '>' not supported between instances of 'NoneType' and 'int'

# %%
img = cv2.imread('../DATASETS/images/lenna.jpg',0)
binary_image = img > 128
plt.figure(figsize=(16,9))
plt.subplot(1,2,1)
plt.imshow(img, cmap = 'gray')
plt.subplot(1,2,2)
plt.imshow(binary_image, cmap = 'gray')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 img = cv2.imread('../DATASETS/images/lenna.jpg',0)
# ----> 2 binary_image = img > 128
#       3 plt.figure(figsize=(16,9))
#       4 plt.subplot(1,2,1)
#
# TypeError: '>' not supported between instances of 'NoneType' and 'int'
