# %%
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(rescale=1/255, zoom_range=0.2,
                                   horizontal_flip=True, shear_range=0.2)

train = train_datagen.flow_from_directory(
    '../../DATASETS/imagenet-new/train',
    class_mode='binary', target_size=(64,64))
# Out:
# Found 5000 images belonging to 10 classes.

# %% [markdown]
# ## BUILD THE MODEL

# %%
# Build the model
model = Sequential()

model.add(Input(shape=(64,64,3)))

model.add(Conv2D(filters=16, kernel_size=(3,3), activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters=8, kernel_size=(3,3), activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(32, activation='relu'))
model.add(Dense(10, activation='softmax')) # Note: updated for the 10-class ImageNet subset
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Build the model
# ----> 2 model = Sequential()
#       4 model.add(Input(shape=(64,64,3)))
#       6 model.add(Conv2D(filters=16, kernel_size=(3,3), activation='relu'))
#
# NameError: name 'Sequential' is not defined

# %%
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 model.compile(
#       2     loss='categorical_crossentropy',
#       3     optimizer='adam',
#       4     metrics=['accuracy']
#       5 )
#
# NameError: name 'model' is not defined

# %%
model.fit(train, epochs=20, batch_size=10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 model.fit(train, epochs=20, batch_size=10)
#
# NameError: name 'model' is not defined

# %%
# Predict the class of an image
res = dict((v,k) for k, v in train.class_indices)
res

# %% [markdown]
# ###  prediction new data
