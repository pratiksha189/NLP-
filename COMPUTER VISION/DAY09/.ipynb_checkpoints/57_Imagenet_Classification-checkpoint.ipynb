# %%
from keras.models import Sequential
from keras.layers import Dense, Input, Conv2D, MaxPool2D, Flatten, Dropout
from keras.utils import plot_model,to_categorical
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(rescale=1/255, zoom_range=0.2,
                                   horizontal_flip = True, shear_range = 0.2)

# %%
train = train_datagen.flow_from_directory(
    '../../DATASETS/imagenet-new/val/images/val_192.JPEG', 
    class_mode = 'categorical',
    target_size = (64,64),
  
)
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 train = train_datagen.flow_from_directory(
#       2     '../../DATASETS/imagenet-new/val/images/val_192.JPEG',
#       3     class_mode = 'categorical',
#       4     target_size = (64,64),
#       5
#       6 )
#
# File c:\Users\PGCP-AI\.conda\envs\dl_env\lib\site-packages\keras\src\preprocessing\image.py:1649, in ImageDataGenerator.flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio)
#    1562 def flow_from_directory(
#    1563     self,
#    1564     directory,
#    (...)
#    1578     keep_aspect_ratio=False,
#    1579 ):
#    1580     """Takes the path to a directory & generates batches of augmented data.
#    1581
#    1582     Args:
#    (...)
# ...

# %%
train.class_indices
# Out:
# {'crocodile': 0,
#  'fish': 1,
#  'fossils': 2,
#  'frog': 3,
#  'insect': 4,
#  'reptiles': 5,
#  'scorpion': 6,
#  'snake': 7,
#  'spider': 8,
#  'toad': 9}

# %%
model = Sequential()

model.add(Input(shape = (64,64,3)))

model.add(Conv2D(64, (3,3), activation = 'relu'))
model.add(MaxPool2D(2,2))

model.add(Conv2D(32, (3,3), activation = 'relu'))
model.add(MaxPool2D(2,2))


model.add(Flatten())

model.add(Dense(32, activation = 'relu'))
model.add(Dense(10, activation = 'sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 62, 62, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 31, 31, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 29, 29, 32)     │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 6272)           │             0 │
# ...

# %%
model.compile(loss= 'sparse_categorical_crossentropy',optimizer= 'adam', metrics=['accuracy'])

# %%
model.fit(train, epochs= 20, batch_size=10)
# Out:
# Epoch 1/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 79s 488ms/step - accuracy: 0.1888 - loss: 2.1918
# Epoch 2/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 14s 89ms/step - accuracy: 0.3458 - loss: 1.8532
# Epoch 3/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 14s 88ms/step - accuracy: 0.4078 - loss: 1.7087
# Epoch 4/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 14s 90ms/step - accuracy: 0.4380 - loss: 1.6347
# Epoch 5/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 14s 90ms/step - accuracy: 0.4552 - loss: 1.5725
# Epoch 6/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 14s 89ms/step - accuracy: 0.4784 - loss: 1.5124
# Epoch 7/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 14s 90ms/step - accuracy: 0.4960 - loss: 1.4538
# Epoch 8/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 14s 90ms/step - accuracy: 0.5102 - loss: 1.4262
# Epoch 9/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 14s 89ms/step - accuracy: 0.5276 - loss: 1.3863
# Epoch 10/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 14s 88ms/step - accuracy: 0.5400 - loss: 1.3513
# Epoch 11/20
# ...

# %% [markdown]
# Predict the class of an image

# %%
result = dict((v,k) for k,v in train.class_indices.items())
result
# Out:
# {0: 'crocodile',
#  1: 'fish',
#  2: 'fossils',
#  3: 'frog',
#  4: 'insect',
#  5: 'reptiles',
#  6: 'scorpion',
#  7: 'snake',
#  8: 'spider',
#  9: 'toad'}

# %%
img = plt.imread('datasets/imagenet-new/val/images/val 192.JPEG')
plt.figure(figsize=(1,1))
plt.imshow(img)
img = img.reshape(1,64,64,3)
pred = model.predict(img)
result[pred.argmax()]
