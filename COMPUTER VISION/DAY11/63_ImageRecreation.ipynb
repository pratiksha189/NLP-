# %%
import matplotlib.pyplot as plt
import cv2
from PIL import Image
import numpy as np

# %%
image=plt.imread('../../DATASETS/images/cat_damaged.png')
image
# Out:
# array([[[0.4627451 , 0.4117647 , 0.3764706 ],
#         [0.46666667, 0.41568628, 0.38039216],
#         [0.47058824, 0.41960785, 0.38431373],
#         ...,
#         [0.72156864, 0.6627451 , 0.5882353 ],
#         [0.7176471 , 0.6509804 , 0.57254905],
#         [0.7137255 , 0.64705884, 0.5686275 ]],
#
#        [[0.45882353, 0.40784314, 0.37254903],
#         [0.4627451 , 0.4117647 , 0.3764706 ],
#         [0.46666667, 0.41568628, 0.38039216],
#         ...,
#         [0.7137255 , 0.64705884, 0.5764706 ],
#         [0.7058824 , 0.6392157 , 0.56078434],
#         [0.7019608 , 0.63529414, 0.5568628 ]],
#
#        [[0.4509804 , 0.4       , 0.3647059 ],
#         [0.45490196, 0.40392157, 0.36862746],
#         [0.45882353, 0.40784314, 0.37254903],
#         ...,
#         [0.7019608 , 0.627451  , 0.56078434],
#         [0.69411767, 0.62352943, 0.54509807],
#         [0.6901961 , 0.61960787, 0.5411765 ]],
#
#        ...,
#
#        [[0.7882353 , 0.8117647 , 0.8117647 ],
#         [0.7882353 , 0.8117647 , 0.8117647 ],
#         [0.7882353 , 0.8117647 , 0.8117647 ],
#         ...,
#         [0.7764706 , 0.7921569 , 0.79607844],
#         [0.78431374, 0.8       , 0.8039216 ],
#         [0.7921569 , 0.80784315, 0.8117647 ]],
#
#        [[0.77254903, 0.79607844, 0.79607844],
#         [0.77254903, 0.79607844, 0.79607844],
#         [0.7764706 , 0.8       , 0.8       ],
#         ...,
#         [0.78431374, 0.8       , 0.8039216 ],
#         [0.7882353 , 0.8039216 , 0.80784315],
#         [0.7882353 , 0.8039216 , 0.80784315]],
#
#        [[0.7607843 , 0.78431374, 0.78431374],
#         [0.7607843 , 0.78431374, 0.78431374],
#         [0.7647059 , 0.7882353 , 0.7882353 ],
#         ...,
#         [0.78431374, 0.8       , 0.8039216 ],
#         [0.78039217, 0.79607844, 0.8       ],
#         [0.7764706 , 0.7921569 , 0.79607844]]], dtype=float32)

# %%
plt.imshow(image)

# %%
image.shape
# Out:
# (400, 400, 3)

# %%
height,width,_=image.shape
height,width
# Out:
# (400, 400)

# %%
mask=np.zeros([height,width,3],dtype=np.uint8)
plt.imshow(mask,cmap='gray')

# %%
for x in range(height):
    for y in range(width):
        if image[x,y].sum() == 0:
            mask[x,y]=[255,255,255]
plt.imshow(mask,cmap='gray')

# %%
plt.subplot(121)
plt.imshow(image)
plt.subplot(122)
plt.imshow(mask,cmap='gray')

# %%
mask = cv2.cvtColor(mask,cv2.COLOR_BGR2GRAY)

# %%
image = cv2.imread('../../DATASETS/images/cat_damaged.png')
dst = cv2.inpaint(image, mask, 3, cv2.INPAINT_NS)

# %%
plt.subplot(121); plt.title('Original Image')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB));
plt.subplot(122); plt.title('Reconstructed Image')
plt.imshow(cv2.cvtColor(dst, cv2.COLOR_BGR2RGB))
