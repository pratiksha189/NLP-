# %%
from keras.applications.resnet50 import ResNet50
from keras.applications.resnet50 import preprocess_input
from keras.applications.resnet50 import decode_predictions
from keras.preprocessing.image import load_img, img_to_array
from keras.utils import plot_model
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
img=load_img('download.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225>

# %%
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
img=img_to_array(img)

# %%
img=cv2.resize(img,(224,224))
img=img.astype(np.uint8)
plt.imshow(img)

# %%
img.shape
# Out:
# (224, 224, 3)

# %%
img_pre = preprocess_input(img)

# %%
model = ResNet50()
# Out:
# ...
# 102967424/102967424 ━━━━━━━━━━━━━━━━━━━━ 8s 0us/step

# %%
reslut = model.predict(img_pre.reshape(1,224,224,3))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step

# %%
decode_predictions(reslut)
# Out:
# ...
# 35363/35363 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# [[('n04350905', 'suit', np.float32(0.6791286)),
#   ('n04591157', 'Windsor_tie', np.float32(0.1881968)),
#   ('n03838899', 'oboe', np.float32(0.020862302)),
#   ('n02804610', 'bassoon', np.float32(0.011091694)),
#   ('n03110669', 'cornet', np.float32(0.0057813437))]]

# %%
import PIL,urllib

# %%
url='https://www.treehugger.com/thmb/vZy1Grg67g139KCatkeMS54sDcw=/750x0/filters:no_upscale():max_bytes(150000):strip_icc():format(webp)/GettyImages-160869327-57f871694a4a4d69b2503f311cf31fbc.jpg'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}
req = urllib.request.Request(url, headers=headers)
img=PIL.Image.open(urllib.request.urlopen(req))
img=np.array(img)
img=cv2.resize(img,(224,224))
img=img.astype(np.uint8)
img_pre=preprocess_input(img)
result=model.predict(img_pre.reshape(1,224,224,3))
decode_predictions(result)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# [[('n02128385', 'leopard', np.float32(0.8854222)),
#   ('n02128925', 'jaguar', np.float32(0.10621384)),
#   ('n02130308', 'cheetah', np.float32(0.006102498)),
#   ('n02128757', 'snow_leopard', np.float32(0.00083571183)),
#   ('n02127052', 'lynx', np.float32(0.00046393994))]]

# %%
img
# Out:
# array([[[ 95,  71,  40],
#         [ 96,  72,  41],
#         [ 98,  73,  43],
#         ...,
#         [171, 137, 107],
#         [171, 137, 107],
#         [175, 141, 112]],
#
#        [[ 94,  70,  39],
#         [ 95,  71,  40],
#         [ 96,  72,  41],
#         ...,
#         [177, 144, 115],
#         [176, 142, 113],
#         [176, 142, 113]],
#
#        [[ 93,  68,  40],
#         [ 94,  69,  41],
#         [ 95,  70,  42],
#         ...,
#         [182, 148, 121],
#         [180, 146, 119],
#         [180, 145, 118]],
#
#        ...,
#
#        [[125, 103,  94],
#         [ 97,  75,  69],
#         [ 80,  58,  52],
#         ...,
#         [175, 148, 135],
#         [139, 109,  96],
#         [145, 116, 103]],
#
#        [[110,  89,  80],
#         [105,  84,  75],
#         [ 80,  58,  50],
#         ...,
#         [144, 114, 104],
#         [124,  96,  83],
#         [131, 103,  90]],
#
#        [[ 85,  64,  55],
#         [113,  92,  83],
#         [107,  86,  77],
# ...

# %%
plot_model(model, show_layer_activations=True , show_layer_names=True , show_trainable=True , show_shapes=True)
