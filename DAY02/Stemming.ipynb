# %%
words1 = 'working', 'worker', 'worked', 'workable'
words2 =  'bigger', 'biggest', 'big'
words3 = 'consulting', 'consultation', 'consulted', 'consultative'
words4 = 'player', 'played', 'players', 'playing', 'plays'

# %%
from nltk.stem import  PorterStemmer, LancasterStemmer

# %%
from nltk.tokenize import word_tokenize
import string
from nltk.corpus import stopwords

# %%
ps = PorterStemmer()

# %%
for word in words1:
    print(word, '->',ps.stem(word))
# Out:
# working -> work
# worker -> worker
# worked -> work
# workable -> workabl

# %%
for tup in [words1, words2, words3, words4]:
    for word in tup:
        print(word, '->',ps.stem(word))
    print("\n")
# Out:
# working -> work
# worker -> worker
# worked -> work
# workable -> workabl
#
#
# bigger -> bigger
# biggest -> biggest
# big -> big
#
#
# consulting -> consult
# consultation -> consult
# consulted -> consult
# consultative -> consult
#
#
# player -> player
# played -> play
# players -> player
# playing -> play
# plays -> play

# %%
ls = LancasterStemmer()

# %%
for tup in [words1, words2, words3, words4]:
    for word in tup:
        print(word, '->',ls.stem(word))
    print("\n")
# Out:
# working -> work
# worker -> work
# worked -> work
# workable -> work
#
#
# bigger -> big
# biggest -> biggest
# big -> big
#
#
# consulting -> consult
# consultation -> consult
# consulted -> consult
# consultative -> consult
#
#
# player -> play
# played -> play
# players -> play
# playing -> play
# plays -> play

# %%
#Remove stopwords, punctuation and suffixes and print the list of words
sent = "Hello friends! How are you? I like Python Programming but my friend likes to program in python"

# %%
swords = stopwords.words("english")

# %%
sent_list = word_tokenize(sent)
porter_stemmer = []
lan_stemmer = []
for word in sent_list:
    if word not in string.punctuation and word.lower() not in swords:
        porter_stemmer.append(ps.stem(word))
        lan_stemmer.append(ls.stem(word))

# %%
print(porter_stemmer) #porter stemmer
print(lan_stemmer) #lancaster stemmer
# Out:
# ['hello', 'friend', 'like', 'python', 'program', 'friend', 'like', 'program', 'python']
# ['hello', 'friend', 'lik', 'python', 'program', 'friend', 'lik', 'program', 'python']

# %%
words1 = 'working', 'worker', 'worked', 'workable'
words2 =  'bigger', 'biggest', 'big'
words3 = 'consulting', 'consultation', 'consulted', 'consultative'
words4 = 'player', 'played', 'players', 'playing', 'plays'

# %%
from nltk.stem import  PorterStemmer, LancasterStemmer

# %%
from nltk.tokenize import word_tokenize
import string
from nltk.corpus import stopwords

# %%
ps = PorterStemmer()

# %%
for word in words1:
    print(word, '->',ps.stem(word))

# %%
for tup in [words1, words2, words3, words4]:
    for word in tup:
        print(word, '->',ps.stem(word))
    print("\n")

# %%
ls = LancasterStemmer()

# %%
for tup in [words1, words2, words3, words4]:
    for word in tup:
        print(word, '->',ls.stem(word))
    print("\n")

# %%
#Remove stopwords, punctuation and suffixes and print the list of words
sent = "Hello friends! How are you? I like Python Programming but my friend likes to program in python"

# %%
swords = stopwords.words("english")

# %%
sent_list = word_tokenize(sent)
porter_stemmer = []
lan_stemmer = []
for word in sent_list:
    if word not in string.punctuation and word.lower() not in swords:
        porter_stemmer.append(ps.stem(word))
        lan_stemmer.append(ls.stem(word))

# %%
print(porter_stemmer) #porter stemmer
print(lan_stemmer) #lancaster stemmer
