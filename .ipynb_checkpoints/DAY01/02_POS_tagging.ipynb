# %%
from nltk.tokenize import word_tokenize
from nltk import pos_tag

# %%
sent='A quick brown fox jumps over the lazy dog'

# %%
tags=pos_tag(word_tokenize(sent))
tags
# Out:
# [('A', 'DT'),
#  ('quick', 'JJ'),
#  ('brown', 'NN'),
#  ('fox', 'NN'),
#  ('jumps', 'VBZ'),
#  ('over', 'IN'),
#  ('the', 'DT'),
#  ('lazy', 'JJ'),
#  ('dog', 'NN')]

# %%
data='''Pune (Marathi: Puṇē, pronounced [ˈpuɳe] ⓘ), previously spelled in English as Poona 
(the official name until 1978),[16][17] is a city in the state of Maharashtra in the Deccan 
Plateau in Western India. It is the administrative headquarters of the Pune district, and of 
Pune division. In terms of the total amount of land under its jurisdiction, Pune is the largest 
city in Maharashtra by area, with a geographical area of 516.18km2,[18] though by population it 
comes in a distant second to Mumbai. According to the 2011 Census of India, Pune has 7.2 million 
residents in the metropolitan region, making it the seventh-most populous metropolitan area in 
India.[19] The city of Pune is part of Pune Metropolitan Region.[20] Pune is one of the largest 
IT hubs in India.[21][22] It is also one of the most important automobile and manufacturing hubs 
of India. Pune is often referred to as the "Oxford of the East" because of its educational institutions
.[23][24][25] It has been ranked "the most liveable city in India" several times'''

# %%
print(data)
# Out:
# Pune (Marathi: Puṇē, pronounced [ˈpuɳe] ⓘ), previously spelled in English as Poona
# (the official name until 1978),[16][17] is a city in the state of Maharashtra in the Deccan
# Plateau in Western India. It is the administrative headquarters of the Pune district, and of
# Pune division. In terms of the total amount of land under its jurisdiction, Pune is the largest
# city in Maharashtra by area, with a geographical area of 516.18km2,[18] though by population it
# comes in a distant second to Mumbai. According to the 2011 Census of India, Pune has 7.2 million
# residents in the metropolitan region, making it the seventh-most populous metropolitan area in
# India.[19] The city of Pune is part of Pune Metropolitan Region.[20] Pune is one of the largest
# IT hubs in India.[21][22] It is also one of the most important automobile and manufacturing hubs
# of India. Pune is often referred to as the "Oxford of the East" because of its educational institutions
# ...

# %%
tags=pos_tag(word_tokenize(data))
tags
# Out:
# [('Pune', 'NNP'),
#  ('(', '('),
#  ('Marathi', 'NNP'),
#  (':', ':'),
#  ('Puṇē', 'NNP'),
#  (',', ','),
#  ('pronounced', 'VBD'),
#  ('[', 'JJ'),
#  ('ˈpuɳe', 'NNP'),
#  (']', 'NNP'),
#  ('ⓘ', 'NNP'),
#  (')', ')'),
#  (',', ','),
#  ('previously', 'RB'),
#  ('spelled', 'VBN'),
#  ('in', 'IN'),
#  ('English', 'NNP'),
#  ('as', 'IN'),
#  ('Poona', 'NNP'),
#  ('(', '('),
#  ('the', 'DT'),
#  ('official', 'NN'),
#  ('name', 'NN'),
#  ('until', 'IN'),
#  ('1978', 'CD'),
#  (')', ')'),
#  (',', ','),
#  ('[', '$'),
#  ('16', 'CD'),
#  (']', 'NNP'),
#  ('[', 'VBD'),
#  ('17', 'CD'),
#  (']', 'NN'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('city', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('state', 'NN'),
#  ('of', 'IN'),
#  ('Maharashtra', 'NNP'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('Deccan', 'NNP'),
#  ('Plateau', 'NNP'),
#  ('in', 'IN'),
#  ('Western', 'JJ'),
#  ('India', 'NNP'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('administrative', 'JJ'),
# ...

# %%
for word,tag in tags:
    if tag.startswith('JJ'):
        print(word)
# Out:
# [
# Western
# administrative
# total
# largest
# geographical
# distant
# metropolitan
# seventh-most
# populous
# metropolitan
# largest
# ]
# important
# educational
# liveable
# several

# %%
l = []
for i in range(0,len(tags)):
    l1 = []
    for j in range(1,len(tags)):
        if 'JJ' in tags[i] and 'NN' in tags[j]:
            l1=[tags[i][0],tags[j][1]]
    if len(l1)!=0:
        l.append(l1)
print(l)
# Out:
# [['[', 'NN'], ['Western', 'NN'], ['administrative', 'NN'], ['total', 'NN'], ['geographical', 'NN'], ['distant', 'NN'], ['metropolitan', 'NN'], ['seventh-most', 'NN'], ['populous', 'NN'], ['metropolitan', 'NN'], [']', 'NN'], ['important', 'NN'], ['educational', 'NN'], ['liveable', 'NN'], ['several', 'NN']]

# %%
pairs = []
for i in range(len(tags)):
    if tags[i][1].startswith('JJ') and tags [i+1][1].startswith('NN'):
        pairs.append([tags[i][0], tags[i+1][0]])

# %%
print(pairs)
# Out:
# [['[', 'ˈpuɳe'], ['Western', 'India'], ['administrative', 'headquarters'], ['total', 'amount'], ['largest', 'city'], ['geographical', 'area'], ['distant', 'second'], ['metropolitan', 'region'], ['metropolitan', 'area'], ['largest', 'IT'], ['important', 'automobile'], ['educational', 'institutions'], ['liveable', 'city'], ['several', 'times']]
