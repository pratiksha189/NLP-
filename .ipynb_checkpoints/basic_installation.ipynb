# %%
# to install imp libraries
# pip install nltk spacy textblob -U
# Out:
# Collecting nltk
#   Downloading nltk-3.9.4-py3-none-any.whl.metadata (3.2 kB)
# Collecting spacy
#   Downloading spacy-3.8.14-cp312-cp312-win_amd64.whl.metadata (28 kB)
# Collecting textblob
#   Downloading textblob-0.20.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: click in C:\Users\PGCP-AI\AppData\Roaming\Python\Python312\site-packages (from nltk) (8.3.3)
# Requirement already satisfied: joblib in C:\Users\PGCP-AI\AppData\Roaming\Python\Python312\site-packages (from nltk) (1.5.3)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2026.5.9-cp312-cp312-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: tqdm in C:\Users\PGCP-AI\.conda\envs\dnn\Lib\site-packages (from nltk) (4.67.3)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Downloading murmurhash-1.0.15-cp312-cp312-win_amd64.whl.metadata (2.3 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Downloading cymem-2.0.13-cp312-cp312-win_amd64.whl.metadata (9.9 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Downloading preshed-3.0.13-cp312-cp312-win_amd64.whl.metadata (5.4 kB)
# Collecting thinc<8.4.0,>=8.3.12 (from spacy)
#   Downloading thinc-8.3.13-cp312-cp312-win_amd64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Downloading wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.5.3 (from spacy)
#   Downloading srsly-2.5.3-cp312-cp312-win_amd64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<2.0.0,>=1.0.0 (from spacy)
#   Downloading weasel-1.0.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting confection<2.0.0,>=1.3.2 (from spacy)
#   Downloading confection-1.3.3-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in C:\Users\PGCP-AI\AppData\Roaming\Python\Python312\site-packages (from spacy) (0.24.2)
# Requirement already satisfied: numpy>=1.19.0 in C:\Users\PGCP-AI\AppData\Roaming\Python\Python312\site-packages (from spacy) (2.4.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in C:\Users\PGCP-AI\.conda\envs\dnn\Lib\site-packages (from spacy) (2.33.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in C:\Users\PGCP-AI\AppData\Roaming\Python\Python312\site-packages (from spacy) (2.13.3)
# Requirement already satisfied: jinja2 in C:\Users\PGCP-AI\.conda\envs\dnn\Lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in C:\Users\PGCP-AI\.conda\envs\dnn\Lib\site-packages (from spacy) (81.0.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\PGCP-AI\.conda\envs\dnn\Lib\site-packages (from spacy) (26.0)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.0.0->spacy)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: pydantic-core==2.46.3 in C:\Users\PGCP-AI\AppData\Roaming\Python\Python312\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.46.3)
# Requirement already satisfied: typing-extensions>=4.14.1 in C:\Users\PGCP-AI\AppData\Roaming\Python\Python312\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\PGCP-AI\AppData\Roaming\Python\Python312\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\PGCP-AI\.conda\envs\dnn\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\PGCP-AI\.conda\envs\dnn\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\PGCP-AI\.conda\envs\dnn\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\PGCP-AI\.conda\envs\dnn\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.4.22)
# Collecting blis<1.4.0,>=1.3.0 (from thinc<8.4.0,>=8.3.12->spacy)
#   Downloading blis-1.3.3-cp312-cp312-win_amd64.whl.metadata (7.7 kB)
# Requirement already satisfied: colorama in C:\Users\PGCP-AI\.conda\envs\dnn\Lib\site-packages (from tqdm->nltk) (0.4.6)
# Collecting shellingham>=1.3.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: rich>=12.3.0 in C:\Users\PGCP-AI\.conda\envs\dnn\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\PGCP-AI\AppData\Roaming\Python\Python312\site-packages (from typer<1.0.0,>=0.3.0->spacy) (0.0.4)
# Collecting cloudpathlib>=0.7.0 (from weasel<2.0.0,>=1.0.0->spacy)
#   Downloading cloudpathlib-0.24.0-py3-none-any.whl.metadata (16 kB)
# Collecting smart-open>=5.2.1 (from weasel<2.0.0,>=1.0.0->spacy)
#   Downloading smart_open-7.6.1-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: httpx>=0.24.0 in C:\Users\PGCP-AI\.conda\envs\dnn\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: anyio in C:\Users\PGCP-AI\.conda\envs\dnn\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.12.1)
# Requirement already satisfied: httpcore==1.* in C:\Users\PGCP-AI\.conda\envs\dnn\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\PGCP-AI\.conda\envs\dnn\Lib\site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\PGCP-AI\.conda\envs\dnn\Lib\site-packages (from rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\PGCP-AI\.conda\envs\dnn\Lib\site-packages (from rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\PGCP-AI\.conda\envs\dnn\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: wrapt in C:\Users\PGCP-AI\.conda\envs\dnn\Lib\site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy) (2.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\PGCP-AI\.conda\envs\dnn\Lib\site-packages (from jinja2->spacy) (3.0.2)
# Downloading nltk-3.9.4-py3-none-any.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    --------------------------- ------------ 1.0/1.6 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 4.1 MB/s  0:00:00
# Downloading spacy-3.8.14-cp312-cp312-win_amd64.whl (14.2 MB)
#    ---------------------------------------- 0.0/14.2 MB ? eta -:--:--
#    - -------------------------------------- 0.5/14.2 MB 3.4 MB/s eta 0:00:05
#    -- ------------------------------------- 1.0/14.2 MB 2.6 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.6/14.2 MB 2.5 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.8/14.2 MB 2.3 MB/s eta 0:00:06
#    ------ --------------------------------- 2.4/14.2 MB 2.3 MB/s eta 0:00:06
#    ------- -------------------------------- 2.6/14.2 MB 2.3 MB/s eta 0:00:06
#    -------- ------------------------------- 3.1/14.2 MB 2.0 MB/s eta 0:00:06
#    --------- ------------------------------ 3.4/14.2 MB 2.0 MB/s eta 0:00:06
#    --------- ------------------------------ 3.4/14.2 MB 2.0 MB/s eta 0:00:06
#    ---------- ----------------------------- 3.7/14.2 MB 1.8 MB/s eta 0:00:06
#    ----------- ---------------------------- 3.9/14.2 MB 1.7 MB/s eta 0:00:07
#    ----------- ---------------------------- 4.2/14.2 MB 1.7 MB/s eta 0:00:07
#    ------------ --------------------------- 4.5/14.2 MB 1.6 MB/s eta 0:00:06
#    -------------- ------------------------- 5.0/14.2 MB 1.6 MB/s eta 0:00:06
#    -------------- ------------------------- 5.2/14.2 MB 1.6 MB/s eta 0:00:06
8 MB/s eta 0:00:02
#    ---------------------------- ----------- 4.5/6.2 MB 1.9 MB/s eta 0:00:01
#    -------------------------------- ------- 5.0/6.2 MB 1.9 MB/s eta 0:00:01
#    --------------------------------- ------ 5.2/6.2 MB 1.9 MB/s eta 0:00:01
#    ------------------------------------- -- 5.8/6.2 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 1.9 MB/s  0:00:03
# Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Downloading weasel-1.0.0-py3-none-any.whl (50 kB)
# Downloading textblob-0.20.0-py3-none-any.whl (624 kB)
#    ---------------------------------------- 0.0/625.0 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/625.0 kB ? eta -:--:--
#    ---------------------------------------- 625.0/625.0 kB 1.4 MB/s  0:00:00
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading cloudpathlib-0.24.0-py3-none-any.whl (63 kB)
# Downloading regex-2026.5.9-cp312-cp312-win_amd64.whl (277 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading smart_open-7.6.1-py3-none-any.whl (64 kB)
# Installing collected packages: wasabi, spacy-loggers, spacy-legacy, smart-open, shellingham, regex, murmurhash, cymem, confection, cloudpathlib, catalogue, blis, annotated-types, srsly, preshed, nltk, thinc, textblob, weasel, spacy
#
#    -- -------------------------------------  1/20 [spacy-loggers]
#    ---- -----------------------------------  2/20 [spacy-legacy]
#    -------- -------------------------------  4/20 [shellingham]
#    ---------- -----------------------------  5/20 [regex]
#    ---------------- -----------------------  8/20 [confection]
#    ------------------ ---------------------  9/20 [cloudpathlib]
#    ---------------------- ----------------- 11/20 [blis]
#    ---------------------- ----------------- 11/20 [blis]
#    -------------------------- ------------- 13/20 [srsly]
#    -------------------------- ------------- 13/20 [srsly]
#    -------------------------- ------------- 13/20 [srsly]
#    -------------------------- ------------- 13/20 [srsly]
#    ---------------------------- ----------- 14/20 [preshed]
#    ------------------------------ --------- 15/20 [nltk]
#    ------------------------------ --------- 15/20 [nltk]
#    ------------------------------ --------- 15/20 [nltk]
#    ------------------------------ --------- 15/20 [nltk]
#    ------------------------------ --------- 15/20 [nltk]
#    ------------------------------ --------- 15/20 [nltk]
#    ------------------------------ --------- 15/20 [nltk]
#    ------------------------------ --------- 15/20 [nltk]
#    ------------------------------ --------- 15/20 [nltk]
#    ------------------------------ --------- 15/20 [nltk]
#    ------------------------------ --------- 15/20 [nltk]
#    ------------------------------ --------- 15/20 [nltk]
#    ------------------------------ --------- 15/20 [nltk]
#    ------------------------------ --------- 15/20 [nltk]
#    ------------------------------ --------- 15/20 [nltk]
#    ------------------------------ --------- 15/20 [nltk]
#    ------------------------------ --------- 15/20 [nltk]
#    -------------------------------- ------- 16/20 [thinc]
#    -------------------------------- ------- 16/20 [thinc]
#    -------------------------------- ------- 16/20 [thinc]
#    -------------------------------- ------- 16/20 [thinc]
#    -------------------------------- ------- 16/20 [thinc]
#    -------------------------------- ------- 16/20 [thinc]
#    -------------------------------- ------- 16/20 [thinc]
#    ---------------------------------- ----- 17/20 [textblob]
#    ------------------------------------ --- 18/20 [weasel]
#    -------------------------------------- - 19/20 [spacy]
#    -------------------------------------- - 19/20 [spacy]
#    -------------------------------------- - 19/20 [spacy]
#    -------------------------------------- - 19/20 [spacy]
#    -------------------------------------- - 19/20 [spacy]
#    -------------------------------------- - 19/20 [spacy]
#    -------------------------------------- - 19/20 [spacy]
#    -------------------------------------- - 19/20 [spacy]
#    -------------------------------------- - 19/20 [spacy]
#    -------------------------------------- - 19/20 [spacy]
#    -------------------------------------- - 19/20 [spacy]
#    -------------------------------------- - 19/20 [spacy]
#    -------------------------------------- - 19/20 [spacy]
#    -------------------------------------- - 19/20 [spacy]
#    -------------------------------------- - 19/20 [spacy]
#    -------------------------------------- - 19/20 [spacy]
#    -------------------------------------- - 19/20 [spacy]
#    -------------------------------------- - 19/20 [spacy]
#    -------------------------------------- - 19/20 [spacy]
#    -------------------------------------- - 19/20 [spacy]
#    -------------------------------------- - 19/20 [spacy]
#    -------------------------------------- - 19/20 [spacy]
#    -------------------------------------- - 19/20 [spacy]
#    -------------------------------------- - 19/20 [spacy]
#    -------------------------------------- - 19/20 [spacy]
#    -------------------------------------- - 19/20 [spacy]
#    -------------------------------------- - 19/20 [spacy]
#    -------------------------------------- - 19/20 [spacy]
#    -------------------------------------- - 19/20 [spacy]
#    -------------------------------------- - 19/20 [spacy]
#    -------------------------------------- - 19/20 [spacy]
#    ---------------------------------------- 20/20 [spacy]
#
# Successfully installed annotated-types-0.7.0 blis-1.3.3 catalogue-2.0.10 cloudpathlib-0.24.0 confection-1.3.3 cymem-2.0.13 murmurhash-1.0.15 nltk-3.9.4 preshed-3.0.13 regex-2026.5.9 shellingham-1.5.4 smart-open-7.6.1 spacy-3.8.14 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.5.3 textblob-0.20.0 thinc-8.3.13 wasabi-1.1.3 weasel-1.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk

# %%
print(nltk.__version__)
# Out:
# 3.9.4

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
#tokenization libraries
nltk.download("punkt")
nltk.download("punkt_tab")
nltk.download("stopwords")

#POS tagging
nltk.download("average_perceptron_tagger")
nltk.download("average_perceptron_tagger_eng")
#nltk.download("punkt")

#wordnet and lemmatization
nltk.download("wordnet")
#indian POS tagging
nltk.download("indian")
#multilingal wordnet
nltk.download("omw-1.4")
# Out:
# [nltk_data] Downloading package punkt to C:\Users\PGCP-
# [nltk_data]     AI\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package punkt_tab to C:\Users\PGCP-
# [nltk_data]     AI\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# [nltk_data] Downloading package stopwords to C:\Users\PGCP-
# [nltk_data]     AI\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Error loading average_perceptron_tagger: Package
# [nltk_data]     'average_perceptron_tagger' not found in index
# [nltk_data] Error loading average_perceptron_tagger_eng: Package
# [nltk_data]     'average_perceptron_tagger_eng' not found in index
# [nltk_data] Downloading package wordnet to C:\Users\PGCP-
# [nltk_data]     AI\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package indian to C:\Users\PGCP-
# [nltk_data]     AI\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\indian.zip.
# [nltk_data] Downloading package omw-1.4 to C:\Users\PGCP-
# [nltk_data]     AI\AppData\Roaming\nltk_data...
# True
