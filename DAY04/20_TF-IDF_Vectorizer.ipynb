# %% [markdown]
# ##### READ THE FILE, REMOVE STOP_WORDS AND CREATE TF*IDF VECTORIZE RESULT

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd


f = open('../DATASETS/mreviews.txt','r')
lines = f.readlines()

# Initialize TF-IDF Vectorizer while filtering out English stop words
tfidf = TfidfVectorizer(stop_words='english')
new = tfidf.fit_transform(lines)

# Create and display the DataFrame
df = pd.DataFrame(new.toarray(), columns=tfidf.get_feature_names_out())
df
# Out:
#     absolute    adding  allowing  audience  authenticity  balancing      best  \
# 0   0.377964  0.000000  0.000000  0.000000      0.000000   0.000000  0.000000
# 1   0.000000  0.000000  0.000000  0.000000      0.000000   0.000000  0.000000
# 2   0.000000  0.000000  0.000000  0.000000      0.000000   0.000000  0.333333
# 3   0.000000  0.000000  0.000000  0.000000      0.000000   0.000000  0.000000
# 4   0.000000  0.000000  0.000000  0.000000      0.000000   0.000000  0.000000
# 5   0.000000  0.000000  0.000000  0.000000      0.324869   0.000000  0.000000
# 6   0.000000  0.000000  0.316228  0.316228      0.000000   0.000000  0.000000
# 7   0.000000  0.308973  0.000000  0.000000      0.000000   0.000000  0.000000
# 8   0.000000  0.000000  0.000000  0.000000      0.000000   0.000000  0.000000
# 9   0.000000  0.000000  0.000000  0.000000      0.000000   0.000000  0.000000
# 10  0.000000  0.000000  0.000000  0.000000      0.000000   0.301511  0.000000
# ...
